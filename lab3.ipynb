# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagraraghav/AI-ML/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implement the missing value, and outler handling data preprocessing techniques on the dataset imported in lab 1

# %%
from google.colab import files
ss = files .upload()
# Out:
#      <input type="file" id="files-1108eae7-5f88-4fd7-b75c-c569279ffd22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1108eae7-5f88-4fd7-b75c-c569279ffd22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import pandas as pd
import numpy as np

# !pip install scikit-learn

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split,cross_val_score,StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer

import missingno as mnso
pd.read_csv("supermarket_sales4.csv")
# Out:
# ...
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty         NaN       7.0  26.1415        NaN
# 1    Electronic accessories         NaN       5.0      NaN    80.2200
# ...

# %%
# data= pd.read_csv("supermarket_sales4.csv")
#data.info()
data=pd.read_csv("supermarket_sales4.csv")

# %%
data['Unit price'].fillna(data['Unit price'].mean(),inplace=True)

# %%
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty   55.700412       7.0  26.1415       NaN
# 1  Electronic accessories   55.700412       5.0      NaN   80.2200
# 2      Home and lifestyle   55.700412       NaN  16.2155       NaN
# 3       Health and beauty   55.700412       8.0  23.2880  489.0480
# ...

# %%
data['Unit price'].fillna(data['Unit price'].median(),inplace=True)

# %%
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       55.23       7.0  26.1415       NaN
# 1  Electronic accessories       55.23       5.0      NaN   80.2200
# 2      Home and lifestyle       55.23       NaN  16.2155       NaN
# 3       Health and beauty       55.23       8.0  23.2880  489.0480
# ...

# %%
data['Unit price'].fillna(data['Unit price'].mode()[0],inplace=True)

# %%
data.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       83.77       7.0  26.1415       NaN
# 1  Electronic accessories       83.77       5.0      NaN   80.2200
# 2      Home and lifestyle       83.77       NaN  16.2155       NaN
# 3       Health and beauty       83.77       8.0  23.2880  489.0480
# ...

# %%
Q1=data['Unit price'].quantile(0.25)
Q1
# Out:
# 32.875

# %%
Q3=data['Unit price'].quantile(0.75)
Q3
# Out:
# 77.98

# %%
IQR = Q3-Q1
IQR
# Out:
# 45.105000000000004

# %%
lower_bound=Q1
lower_bound
# Out:
# 32.875

# %%
upper_bound=Q3
upper_bound
# Out:
# 77.98

# %%
data=data[(data['Unit price'] > lower_bound) & (data['Unit price'] < upper_bound)]
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
# 17  765-26-6951      A     Yangon        Normal    Male
# 18  329-62-1586      A     Yangon        Normal    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 7       Home and lifestyle       73.56       NaN  36.7800  772.3800
# 8        Health and beauty       36.26       2.0   3.6260   76.1460
# 9       Food and beverages       54.84       3.0   8.2260  172.7460
# ...

# %%
data['Unit price'] = np.where(data['Unit price'] > upper_bound , upper_bound,data['Unit price'])
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
# 17  765-26-6951      A     Yangon        Normal    Male
# 18  329-62-1586      A     Yangon        Normal    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 7       Home and lifestyle       73.56       NaN  36.7800  772.3800
# 8        Health and beauty       36.26       2.0   3.6260   76.1460
# 9       Food and beverages       54.84       3.0   8.2260  172.7460
# ...

# %%
data['Unit price'] = np.where(data['Unit price'] < lower_bound , lower_bound,data['Unit price'])
data.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 16  656-95-9349      A     Yangon        Member  Female
# 17  765-26-6951      A     Yangon        Normal    Male
# 18  329-62-1586      A     Yangon        Normal    Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 7       Home and lifestyle       73.56       NaN  36.7800  772.3800
# 8        Health and beauty       36.26       2.0   3.6260   76.1460
# 9       Food and beverages       54.84       3.0   8.2260  172.7460
# ...

# %%
data['Unit price'] = np.log(data['Unit price'])
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# ..           ...    ...        ...           ...     ...
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 6    Electronic accessories    4.231785       6.0  20.6520  433.6920
# 7        Home and lifestyle    4.298101       NaN  36.7800  772.3800
# 8         Health and beauty    3.590715       2.0   3.6260   76.1460
# ...
